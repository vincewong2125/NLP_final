# %%
import pandas as pd
import string
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
from wordcloud import WordCloud
import nltk
import nltk.data
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk import word_tokenize
nltk.download('vader_lexicon')
nltk.download('punkt')
import warnings
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/vincewong/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/vincewong/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_csv('tcc_ceds_music.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'artist_name', 'track_name', 'release_date', 'genre',
#        'lyrics', 'len', 'dating', 'violence', 'world/life', 'night/time',
#        'shake the audience', 'family/gospel', 'romantic', 'communication',
#        'obscene', 'music', 'movement/places', 'light/visual perceptions',
#        'family/spiritual', 'like/girls', 'sadness', 'feelings', 'danceability',
#        'loudness', 'acousticness', 'instrumentalness', 'valence', 'energy',
#        'topic', 'age'],
#       dtype='object')

# %%
df = df[['artist_name', 'track_name', 'release_date', 'genre', 'lyrics']]

# %%
df
# Out:
#                 artist_name                     track_name  release_date  \
# 0                    mukesh           mohabbat bhi jhoothi          1950
# 1             frankie laine                      i believe          1950
# 2               johnnie ray                            cry          1950
# 3               pérez prado                       patricia          1950
# 4      giorgos papadopoulos             apopse eida oneiro          1950
# ...                     ...                            ...           ...
# 28367               mack 10                10 million ways          2019
# 28368                m.o.p.  ante up (robbin hoodz theory)          2019
# 28369                  nine                  whutcha want?          2019
# 28370            will smith                         switch          2019
# 28371                 jeezy                         r.i.p.          2019
#
#          genre                                             lyrics
# 0          pop  hold time feel break feel untrue convince spea...
# 1          pop  believe drop rain fall grow believe darkest ni...
# 2          pop  sweetheart send letter goodbye secret feel bet...
# 3          pop  kiss lips want stroll charm mambo chacha merin...
# 4          pop  till darling till matter know till dream live ...
# ...        ...                                                ...
# 28367  hip hop  cause fuck leave scar tick tock clock come kno...
# 28368  hip hop  minks things chain ring braclets yap fame come...
# 28369  hip hop  get ban get ban stick crack relax plan attack ...
# 28370  hip hop  check check yeah yeah hear thing call switch g...
# 28371  hip hop  remix killer alive remix thriller trap bitch s...
#
# [28372 rows x 5 columns]

# %%
df.genre.unique()
# Out:
# array(['pop', 'country', 'blues', 'jazz', 'reggae', 'rock', 'hip hop'],
#       dtype=object)

# %%
def lyrics_to_words(document):
    """
    This function splits the text of lyrics to  single words, removing stopwords and doing the lemmatization to each word

    parameters:
    document: text to split to single words
    """
    stop_words = set(stopwords.words('english'))
    exclude = set(string.punctuation)
    lemma = WordNetLemmatizer()
    stopwordremoval = " ".join([i for i in document.lower().split() if i not in stop_words])
    punctuationremoval = ''.join(ch for ch in stopwordremoval if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punctuationremoval.split())
    return normalized

# %%
def toword(df):
    def unique(list1):
        # intilize a null list
        unique_list = []
       # traverse for all elements
        for x in list1:
             # check if exists in unique_list or not
                if x not in unique_list:
                    unique_list.append(x)
        return unique_list
    words = []
    #iterate trought each lyric and split unique words appending the result into the words list
    df = df.reset_index(drop=True)
    for word in df['lyrics'].tolist():
        words.append(unique(lyrics_to_words(word).split()))
    #create the new column with the information of words lists
    df['words'] = words
    return df

# %%
def countword(df):      
    c=[]
    for word in df['lyrics']:
        for w in word:
            c.append(w)
    return c

# %%
def words_stats(df,main_df):
    unique_words = []
    total_words = []
    total_news = []
    name = []
    
    for value in df.columns[1:]:
        unique_words.append(np.count_nonzero(df[value]))
        total_words.append(sum(df[value]))
        name.append(str(value))
        total_news.append(main_df['name'][main_df['name']==value].count())
        data = pd.DataFrame({'name':name,
                          'unique words':unique_words,
                          'total words':total_words,
                          'total songs':total_news})
    data['words per songs'] = round(data['total words'] / data['total songs'],0)
    data['words per songs'] = data['words per songs'].astype('int')
    return data

# %%
def my_stop_words(var_in):
    from nltk.corpus import stopwords
    sw = stopwords.words('english')
    tmp = [word for word in var_in.split() if word not in sw]
    tmp = ' '.join(tmp)
    return tmp

# %%
df['lyrics']=df['lyrics'].apply(my_stop_words)
df
# Out:
#                 artist_name                     track_name  release_date  \
# 0                    mukesh           mohabbat bhi jhoothi          1950
# 1             frankie laine                      i believe          1950
# 2               johnnie ray                            cry          1950
# 3               pérez prado                       patricia          1950
# 4      giorgos papadopoulos             apopse eida oneiro          1950
# ...                     ...                            ...           ...
# 28367               mack 10                10 million ways          2019
# 28368                m.o.p.  ante up (robbin hoodz theory)          2019
# 28369                  nine                  whutcha want?          2019
# 28370            will smith                         switch          2019
# 28371                 jeezy                         r.i.p.          2019
#
#          genre                                             lyrics
# 0          pop  hold time feel break feel untrue convince spea...
# 1          pop  believe drop rain fall grow believe darkest ni...
# 2          pop  sweetheart send letter goodbye secret feel bet...
# 3          pop  kiss lips want stroll charm mambo chacha merin...
# 4          pop  till darling till matter know till dream live ...
# ...        ...                                                ...
# 28367  hip hop  cause fuck leave scar tick tock clock come kno...
# 28368  hip hop  minks things chain ring braclets yap fame come...
# 28369  hip hop  get ban get ban stick crack relax plan attack ...
# 28370  hip hop  check check yeah yeah hear thing call switch g...
# 28371  hip hop  remix killer alive remix thriller trap bitch s...
#
# [28372 rows x 5 columns]

# %%
df_w=toword(df)

# %%
df_w
# Out:
#                 artist_name                     track_name  release_date  \
# 0                    mukesh           mohabbat bhi jhoothi          1950
# 1             frankie laine                      i believe          1950
# 2               johnnie ray                            cry          1950
# 3               pérez prado                       patricia          1950
# 4      giorgos papadopoulos             apopse eida oneiro          1950
# ...                     ...                            ...           ...
# 28367               mack 10                10 million ways          2019
# 28368                m.o.p.  ante up (robbin hoodz theory)          2019
# 28369                  nine                  whutcha want?          2019
# 28370            will smith                         switch          2019
# 28371                 jeezy                         r.i.p.          2019
#
#          genre                                             lyrics  \
# 0          pop  hold time feel break feel untrue convince spea...
# 1          pop  believe drop rain fall grow believe darkest ni...
# 2          pop  sweetheart send letter goodbye secret feel bet...
# 3          pop  kiss lips want stroll charm mambo chacha merin...
# 4          pop  till darling till matter know till dream live ...
# ...        ...                                                ...
# 28367  hip hop  cause fuck leave scar tick tock clock come kno...
# 28368  hip hop  minks things chain ring braclets yap fame come...
# 28369  hip hop  get ban get ban stick crack relax plan attack ...
# 28370  hip hop  check check yeah yeah hear thing call switch g...
# 28371  hip hop  remix killer alive remix thriller trap bitch s...
#
#                                                    words
# 0      [hold, time, feel, break, untrue, convince, sp...
# 1      [believe, drop, rain, fall, grow, darkest, nig...
# 2      [sweetheart, send, letter, goodbye, secret, fe...
# 3      [kiss, lip, want, stroll, charm, mambo, chacha...
# 4      [till, darling, matter, know, dream, live, apa...
# ...                                                  ...
# 28367  [cause, fuck, leave, scar, tick, tock, clock, ...
# 28368  [mink, thing, chain, ring, braclets, yap, fame...
# 28369  [get, ban, stick, crack, relax, plan, attack, ...
# 28370  [check, yeah, hear, thing, call, switch, go, t...
# 28371  [remix, killer, alive, thriller, trap, bitch, ...
#
# [28372 rows x 6 columns]

# %%
df_w = df_w[df_w['release_date'].between(2000, 2019)]

# %%
df_w.reset_index(inplace=True)

# %%
df_w
# Out:
#        index   artist_name                     track_name  release_date  \
# 0       4751  3 doors down                   duck and run          2000
# 1       4752  ricky nelson                 hello mary lou          2000
# 2       4753  modest mouse               perfect disguise          2000
# 3       4754           joe               i believe in you          2000
# 4       4755          fuel                   empty spaces          2000
# ...      ...           ...                            ...           ...
# 10407  28367       mack 10                10 million ways          2019
# 10408  28368        m.o.p.  ante up (robbin hoodz theory)          2019
# 10409  28369          nine                  whutcha want?          2019
# 10410  28370    will smith                         switch          2019
# 10411  28371         jeezy                         r.i.p.          2019
#
#          genre                                             lyrics  \
# 0          pop  world unimportant free country tell cost live ...
# 1          pop  hello goodbye heart sweet know hello goodbye h...
# 2          pop  perfect disguise look okay best worst cause co...
# 3          pop  believe dream believe like arrow heart believe...
# 4          pop  mister maybe lend hand help drown starve soull...
# ...        ...                                                ...
# 10407  hip hop  cause fuck leave scar tick tock clock come kno...
# 10408  hip hop  minks things chain ring braclets yap fame come...
# 10409  hip hop  get ban get ban stick crack relax plan attack ...
# 10410  hip hop  check check yeah yeah hear thing call switch g...
# 10411  hip hop  remix killer alive remix thriller trap bitch s...
#
#                                                    words
# 0      [world, unimportant, free, country, tell, cost...
# 1      [hello, goodbye, heart, sweet, know, pas, flas...
# 2      [perfect, disguise, look, okay, best, worst, c...
# 3      [believe, dream, like, arrow, heart, miracle, ...
# 4      [mister, maybe, lend, hand, help, drown, starv...
# ...                                                  ...
# 10407  [cause, fuck, leave, scar, tick, tock, clock, ...
# 10408  [mink, thing, chain, ring, braclets, yap, fame...
# 10409  [get, ban, stick, crack, relax, plan, attack, ...
# 10410  [check, yeah, hear, thing, call, switch, go, t...
# 10411  [remix, killer, alive, thriller, trap, bitch, ...
#
# [10412 rows x 7 columns]

# %%
df_w.release_date.unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %%
before=[]
after=[]
length=[]
ulength=[]
wd=[]


a,b=df.shape
before.append(a)
    

a,b=df_w.shape
after.append(a)  
c=countword(df_w)
l=len(c)
ul=len(np.unique(c))
wd.append(c)
length.append(l)
ulength.append(ul)

# %%
def setimentanalyzer(df):
    neg='Negative'
    neu='Neutral'
    pos='Positive'
    negative = []
    neutral = []
    positive = []
    dominant_sentiment=[]
    dominant_sentiment_score=[]
    #Initialize the model
    sid = SentimentIntensityAnalyzer()
    #Iterate for each row of lyrics and append the scores
    for i in df.index:
       
        scores = sid.polarity_scores(df_w['lyrics'].iloc[i])
        negative.append(scores['neg'])
        neutral.append(scores['neu'])
        positive.append(scores['pos'])
        if (scores['neg']-scores['pos'])>=.05:
            dominant_sentiment_score.append(scores['neg'])
            dominant_sentiment.append(neg)
        elif (scores['pos']-scores['neg'])>=.05:
            dominant_sentiment_score.append(scores['pos'])
            dominant_sentiment.append(pos)
        else:
            dominant_sentiment_score.append(scores['neu'])
            dominant_sentiment.append(neu)
    #Create 5 columns to the main data frame  for each score
    df['negative'] = negative
    df['neutral'] = neutral
    df['positive'] = positive
    df['dominant_sentiment']=dominant_sentiment
    df['dominant_sentiment_score']=dominant_sentiment_score
    return df

# %%
df_sentiment=setimentanalyzer(df_w)
df_sentiment
# Out:
#        index   artist_name                     track_name  release_date  \
# 0       4751  3 doors down                   duck and run          2000
# 1       4752  ricky nelson                 hello mary lou          2000
# 2       4753  modest mouse               perfect disguise          2000
# 3       4754           joe               i believe in you          2000
# 4       4755          fuel                   empty spaces          2000
# ...      ...           ...                            ...           ...
# 10407  28367       mack 10                10 million ways          2019
# 10408  28368        m.o.p.  ante up (robbin hoodz theory)          2019
# 10409  28369          nine                  whutcha want?          2019
# 10410  28370    will smith                         switch          2019
# 10411  28371         jeezy                         r.i.p.          2019
#
#          genre                                             lyrics  \
# 0          pop  world unimportant free country tell cost live ...
# 1          pop  hello goodbye heart sweet know hello goodbye h...
# 2          pop  perfect disguise look okay best worst cause co...
# 3          pop  believe dream believe like arrow heart believe...
# 4          pop  mister maybe lend hand help drown starve soull...
# ...        ...                                                ...
# 10407  hip hop  cause fuck leave scar tick tock clock come kno...
# 10408  hip hop  minks things chain ring braclets yap fame come...
# 10409  hip hop  get ban get ban stick crack relax plan attack ...
# 10410  hip hop  check check yeah yeah hear thing call switch g...
# 10411  hip hop  remix killer alive remix thriller trap bitch s...
#
#                                                    words  negative  neutral  \
# 0      [world, unimportant, free, country, tell, cost...     0.208    0.753
# 1      [hello, goodbye, heart, sweet, know, pas, flas...     0.018    0.780
# 2      [perfect, disguise, look, okay, best, worst, c...     0.348    0.321
# 3      [believe, dream, like, arrow, heart, miracle, ...     0.016    0.596
# 4      [mister, maybe, lend, hand, help, drown, starv...     0.375    0.497
# ...                                                  ...       ...      ...
# 10407  [cause, fuck, leave, scar, tick, tock, clock, ...     0.228    0.685
# 10408  [mink, thing, chain, ring, braclets, yap, fame...     0.242    0.539
# 10409  [get, ban, stick, crack, relax, plan, attack, ...     0.190    0.634
# 10410  [check, yeah, hear, thing, call, switch, go, t...     0.068    0.706
# 10411  [remix, killer, alive, thriller, trap, bitch, ...     0.508    0.382
#
#        positive dominant_sentiment  dominant_sentiment_score
# 0         0.039           Negative                     0.208
# 1         0.202           Positive                     0.202
# 2         0.332            Neutral                     0.321
# 3         0.388           Positive                     0.388
# 4         0.128           Negative                     0.375
# ...         ...                ...                       ...
# 10407     0.087           Negative                     0.228
# 10408     0.219            Neutral                     0.539
# 10409     0.176            Neutral                     0.634
# 10410     0.226           Positive                     0.226
# 10411     0.109           Negative                     0.508
#
# [10412 rows x 12 columns]

# %%
df_sentiment.loc[df_sentiment.neutral==1]
# Out:
#        index           artist_name                    track_name  \
# 569     5320              gorillaz                   white light
# 703     5454  they might be giants  mickey mouse clubhouse theme
# 940     5691           fleet foxes           white winter hymnal
# 1069    5820            phantogram                when i'm small
# 1418    6169        brandi carlile               heart's content
# ...      ...                   ...                           ...
# 9474   27393            half•alive                         arrow
# 9653   27613              dj drama    hip- hop (out in the dark)
# 9764   27724               mod sun   keep it movin' (ft. p.o.s.)
# 9932   27892         radioinactive        left handed cigarettes
# 10373  28333              young mc                   bust a move
#
#        release_date    genre  \
# 569            2005      pop
# 703            2006      pop
# 940            2008      pop
# 1069           2009      pop
# 1418           2012      pop
# ...             ...      ...
# 9474           2019     rock
# 9653           2008  hip hop
# 9764           2010  hip hop
# 9932           2014  hip hop
# 10373          2019  hip hop
#
#                                                   lyrics  \
# 569    white light white light white light alcohol al...
# 703    mouse mouse mouse clubhouse come inside inside...
# 940    follow follow follow follow follow follow foll...
# 1069   underground mouth fee underground underground ...
# 1418   maybe think hang moon maybe think maybe think ...
# ...                                                  ...
# 9474   life begin happen plan somethin tryna somebody...
# 9653                               nuthin summer version
# 9764   hippy picture sunrise skaff girlfriend hippy v...
# 9932   time come bling bling bling bling bling bling ...
# 10373  world world world world world world world worl...
#
#                                                    words  negative  neutral  \
# 569                              [white, light, alcohol]       0.0      1.0
# 703    [mouse, clubhouse, come, inside, roll, present...       0.0      1.0
# 940                          [follow, lyric, commercial]       0.0      1.0
# 1069   [underground, mouth, fee, mouse, deep, lyric, ...       0.0      1.0
# 1418   [maybe, think, hang, moon, speak, soon, tell, ...       0.0      1.0
# ...                                                  ...       ...      ...
# 9474   [life, begin, happen, plan, somethin, tryna, s...       0.0      1.0
# 9653                           [nuthin, summer, version]       0.0      1.0
# 9764   [hippy, picture, sunrise, skaff, girlfriend, v...       0.0      1.0
# 9932                                 [time, come, bling]       0.0      1.0
# 10373                         [world, lyric, commercial]       0.0      1.0
#
#        positive dominant_sentiment  dominant_sentiment_score
# 569         0.0            Neutral                       1.0
# 703         0.0            Neutral                       1.0
# 940         0.0            Neutral                       1.0
# 1069        0.0            Neutral                       1.0
# 1418        0.0            Neutral                       1.0
# ...         ...                ...                       ...
# 9474        0.0            Neutral                       1.0
# 9653        0.0            Neutral                       1.0
# 9764        0.0            Neutral                       1.0
# 9932        0.0            Neutral                       1.0
# 10373       0.0            Neutral                       1.0
#
# [108 rows x 12 columns]

# %%
df_temp=[]
name=df_sentiment['genre'].unique()
name=name[0:7]
num_plots = 7
total_cols = 3
total_rows = 3
#fig, axs = plt.subplots(nrows=total_rows, ncols=total_cols,
fig, axs = plt.subplots(nrows=total_rows, ncols=total_cols,
                        figsize=(5*total_cols, 5*total_rows), constrained_layout=True)
for genre in df_w['genre'].unique():
    df_temp.append(df_sentiment[df_sentiment['genre']==genre])
for i, var in enumerate(name):
    row = i//total_cols
    pos = i % total_cols
    plot = sns.swarmplot(data=df_temp[i], order=['Positive','Negative','Neutral'],  x="dominant_sentiment", y="dominant_sentiment_score",ax=axs[row][pos])
    axs[row][pos].set_title(name[i])
    
name=df_w['genre'].unique()
name=name[6:8]

# %%
means_df = df_sentiment.groupby(['genre']).mean()
means_df
# Out:
#            index  release_date  negative   neutral  positive  \
# genre
# blues    16252.0   2010.090042  0.198438  0.586375  0.215190
# country  11795.5   2009.400145  0.166687  0.595393  0.237920
# hip hop  27940.0   2013.697567  0.224112  0.590463  0.185415
# jazz     20229.0   2009.644728  0.191417  0.581164  0.227429
# pop       5896.0   2009.638149  0.201308  0.570577  0.228107
# reggae   22795.0   2009.971809  0.185062  0.581841  0.233094
# rock     26713.0   2010.084162  0.218714  0.569710  0.211568
#
#          dominant_sentiment_score
# genre
# blues                    0.403552
# country                  0.377585
# hip hop                  0.374074
# jazz                     0.392195
# pop                      0.385952
# reggae                   0.384305
# rock                     0.387537

# %%
x = np.linspace(0, 10, 1000)
for name, group in means_df.groupby('genre'):
    plt.scatter(group['positive'],group['negative'],label=name)
    plt.legend()
plt.xlim([0,0.3])
plt.ylim([0,0.3])
plt.plot(x, x+0, linestyle='solid')
plt.title("Positive Valence vs Negative  Valence")
plt.xlabel('Positive Valence')
plt.ylabel('Negative  Valence')
plt.show()#positive and negative

# %%
# df_info =pd.DataFrame({'before':before,'after':after,'words':wd,'unique words':ulength,'word count':length})
# df_info['diff']=df_info['before']-df_info['after']
# df_info['words per songs'] = round(df_info['word count'] / df_info['after'],0)
# df_info['words per songs'] = df_info['words per songs'].astype('int')
# df_info['lexicalrichness']=(df_info['unique words']/df_info['word count'])*100
# #df_info=df_info[['name','before','after','diff','words','words per songs','unique words','word count','lexicalrichness']]
# df_info

# %% [markdown]
# ## Word Clouds

# %%
def censor(sentence):
    badwords = ("fuck", 'nigga', "shit", 'bitch', 'fuckin') 
    for index, word in enumerate(sentence):
        if any(badword in word for badword in badwords):
            sentence[index] = word[0]
            sentence[index] = ''.join(['*' if c.isalpha() else c for c in word])      
    res =  ' '.join(sentence)
    return res

# %%
df_sentiment['clean_words'] = df_sentiment['words'].apply(censor)

# %%
import matplotlib.pyplot as plt
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");

# %%
# Import package
from wordcloud import WordCloud, STOPWORDS

# %%
pop = df_sentiment.loc[df_sentiment['genre'] == 'pop']
blues = df_sentiment.loc[df_sentiment['genre'] == 'blues']
country = df_sentiment.loc[df_sentiment['genre'] == 'country']
hiphop = df_sentiment.loc[df_sentiment['genre'] == 'hip hop']
jazz = df_sentiment.loc[df_sentiment['genre'] == 'jazz']
reggae =  df_sentiment.loc[df_sentiment['genre'] == 'reggae']
rock =  df_sentiment.loc[df_sentiment['genre'] == 'rock']

# %%
genres = [pop,blues,country,hiphop,jazz,reggae,rock]
lyrics_lst = []
for i in genres:
    text = " ".join(j for j in i.lyrics)
    lyrics_lst.append(text)

# %%
for i in lyrics_lst:
    wordcloud = WordCloud(width = 3000, height = 2000, random_state=1, background_color='white', colormap='Set2', collocations=False, stopwords = STOPWORDS).generate(i)
    plot_cloud(wordcloud)

# %%
wordcloud = WordCloud(width = 3000, height = 2000, random_state=1, background_color='white', colormap='Set2', collocations=False, stopwords = STOPWORDS).generate(poptext)
# Plot
plot_cloud(wordcloud)
